# %% [markdown]
# # Essential Machine Learning for Physicists
#
# <p align="right">
#   <img src="../../misc/tum-logo.png" width="93" align="right" />
#   <img src="../../misc/sixt-logo.png" width="70" align="right" />
# <left><em>&copy; Zinonas Zinonos</em></left>
#
# <left><em>For more information, visit <a href='https://github.com/zinon/essential-machine-learning-for-physicists'>essential-machine-learning-for-physicists</a></em></left>.
# ___
# </p>

# %% [markdown]
# # Stellar Classification
#
#
# ## Context
#
# In astronomy, stellar classification is the classification of stars based on their spectral characteristics. The classification scheme of galaxies, quasars, and stars is one of the most fundamental in astronomy. The early cataloguing of stars and their distribution in the sky has led to the understanding that they make up our own galaxy and, following the distinction that Andromeda was a separate galaxy to our own, numerous galaxies began to be surveyed as more powerful telescopes were built. This datasat aims to classificate stars, galaxies, and quasars based on their spectral characteristics.
#
# ## Content
# The data consists of 100,000 observations of space taken by the SDSS (Sloan Digital Sky Survey). Every observation is described by 17 feature columns and 1 class column which identifies it to be either a `star`, `galaxy` or `quasar`.
#
# - `obj_ID` = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS
# - `alpha` = Right Ascension angle (at J2000 epoch)
# - `delta` = Declination angle (at J2000 epoch)
# - `u` = Ultraviolet filter in the photometric system
# - `g` = Green filter in the photometric system
# - `r` = Red filter in the photometric system
# - `i` = Near Infrared filter in the photometric system
# - `z` = Infrared filter in the photometric system
# - `run_ID` = Run Number used to identify the specific scan
# - `rereun_ID` = Rerun Number to specify how the image was processed
# - `cam_col` = Camera column to identify the scanline within the run
# - `field_ID` = Field number to identify each field
# - `spec_obj_ID` = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class)
# - `class` = object class (`galaxy`, `star` or `quasar` object)
# - `redshift` = redshift value based on the increase in wavelength
# - `plate` = plate ID, identifies each plate in SDSS
# - `MJD` = Modified Julian Date, used to indicate when a given piece of SDSS data was taken
# - `fiber_ID` = fiber ID that identifies the fiber that pointed the light at the focal plane in each observation
#
# <img src="../../misc/SDSS.jpg" width="800">
#
# ## Citation
# fedesoriano. (January 2022). Stellar Classification Dataset - SDSS17.
#
# ## License
# The data released by the SDSS is under public domain. Its taken from the current data release RD17.
#
# More information about the license: http://www.sdss.org/science/image-gallery/
#
# SDSS Publications:
# Abdurro’uf et al., The Seventeenth data release of the Sloan Digital Sky Surveys: Complete Release of MaNGA, MaStar and APOGEE-2 DATA (Abdurro’uf et al. submitted to ApJS) [arXiv:2112.02026]

# %%
#
# IMPORTS HERE
#

# %% [markdown]
# # Task: Load the dataset
#
# The file is called `star_classification.csv.zip` and is located in the `datasets/` subfolder. Display the first 10 rows.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
#          alpha      delta         u         g         r         i         z  \
# 0   135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1   144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2   142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 4   345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
# 5   340.995121  20.589476  23.48827  23.33776  21.32195  20.25615  19.54544
# 6    23.234926  11.418188  21.46973  21.17624  20.92829  20.60826  20.42573
# 7     5.433176  12.065186  22.24979  22.02172  20.34126  19.48794  18.84999
# 8   200.290475  47.199402  24.40286  22.35669  20.61032  19.46490  18.95852
# 9    39.149691  28.102842  21.74669  20.03493  19.17553  18.81823  18.65422
# 10  328.092076  18.220310  25.77163  22.52042  20.63884  19.78071  19.05765
#
#             spec_obj_ID  class  redshift  plate
# 0   6543777369295181824      0  0.634794   5812
# ...

# %% [markdown]
# # Task: display the feature data types

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# obj_ID         float64
# alpha          float64
# delta          float64
# u              float64
# g              float64
# r              float64
# i              float64
# z              float64
# run_ID           int64
# rerun_ID         int64
# cam_col          int64
# field_ID         int64
# spec_obj_ID    float64
# class           object
# redshift       float64
# plate            int64
# MJD              int64
# fiber_ID         int64
# dtype: object

# %% [markdown]
# # Task: Change some feature types
#
# Set the `spec_obj_ID`feature to integer.

# %%
#
# code
#

# %% [markdown]
# # Task: Count the frequency of each element from the 'class'

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# GALAXY    59445
# STAR      21594
# QSO       18961
# Name: class, dtype: int64

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# # Task: Drop the unnecessary columns
#
# Drop the following collumns:
# 1. obj_ID
# 2. run_ID
# 3. rerun_ID
# 4. field_ID
# 5. fiber_ID
# 6. cam_col
# 7. MJD
#
# Feature `obj_ID` gives the unique identifier for the observations.
#
# Feature `run_ID` is a number which is unique for all observations.
#
# Feature `rerun_ID` is an identifier to specify how the image was processed.
#
# Feature `field_ID` is the field number to identify each field.
#
# Feature `fiber_ID` is fiber ID that identifies the fiber that pointed the light at the focal plane in each observation.
#
# Feature `cam_col` is the camera column to identify the scanline within the run.
#
# Feature `MJD` is Modified Julian Date, used to indicate when a given piece of SDSS data was taken
# Since feature `MJD` is a form of Date, it shouldn't be used for modeling.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
#             alpha      delta         u         g         r         i  \
# 0      135.689107  32.494632  23.87882  22.27530  20.39501  19.16573
# 1      144.826101  31.274185  24.77759  22.83188  22.58444  21.16812
# 2      142.188790  35.582444  25.26307  22.66389  20.60976  19.34857
# 3      338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454
# 4      345.282593  21.183866  19.43718  17.58028  16.49747  15.97711
# ...           ...        ...       ...       ...       ...       ...
# 99995   39.620709  -2.594074  22.16759  22.97586  21.90404  21.30548
# 99996   29.493819  19.798874  22.69118  22.38628  20.45003  19.75759
# 99997  224.587407  15.700707  21.16916  19.26997  18.20428  17.69034
# 99998  212.268621  46.660365  25.35039  21.63757  19.91386  19.07254
# 99999  196.896053  49.464643  22.62171  21.79745  20.60115  20.00959
#
#               z          spec_obj_ID   class  redshift  plate
# 0      18.79371  6543777369295181824  GALAXY  0.634794   5812
# ...

# %% [markdown]
# # Task: Describe the statistics of the dataframe

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
#                 count          mean           std           min           25%  \
# alpha        100000.0  1.776291e+02  9.650224e+01  5.527828e-03  1.275182e+02
# delta        100000.0  2.413530e+01  1.964467e+01 -1.878533e+01  5.146771e+00
# u            100000.0  2.198047e+01  3.176929e+01 -9.999000e+03  2.035235e+01
# g            100000.0  2.053139e+01  3.175029e+01 -9.999000e+03  1.896523e+01
# r            100000.0  1.964576e+01  1.854760e+00  9.822070e+00  1.813583e+01
# i            100000.0  1.908485e+01  1.757895e+00  9.469903e+00  1.773228e+01
# z            100000.0  1.866881e+01  3.172815e+01 -9.999000e+03  1.746068e+01
# spec_obj_ID  100000.0  2.177045e+18  5.825494e+18 -9.223372e+18  1.042648e+18
# redshift     100000.0  5.766608e-01  7.307073e-01 -9.970667e-03  5.451684e-02
# plate        100000.0  5.137010e+03  2.952303e+03  2.660000e+02  2.526000e+03
#
#                       50%           75%           max
# alpha        1.809007e+02  2.338950e+02  3.599998e+02
# ...

# %% [markdown]
# # Task: Check for missing values

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# False

# %% [markdown]
# # Task: label-encode the target classes
#
# You can manually assign codes to the target flags or just you scikit-learn's `LabelEncoder`. show the dataframe with the resulting class column.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
#             alpha      delta         u         g         r         i  \
# 0      135.689107  32.494632  23.87882  22.27530  20.39501  19.16573
# 1      144.826101  31.274185  24.77759  22.83188  22.58444  21.16812
# 2      142.188790  35.582444  25.26307  22.66389  20.60976  19.34857
# 3      338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454
# 4      345.282593  21.183866  19.43718  17.58028  16.49747  15.97711
# ...           ...        ...       ...       ...       ...       ...
# 99995   39.620709  -2.594074  22.16759  22.97586  21.90404  21.30548
# 99996   29.493819  19.798874  22.69118  22.38628  20.45003  19.75759
# 99997  224.587407  15.700707  21.16916  19.26997  18.20428  17.69034
# 99998  212.268621  46.660365  25.35039  21.63757  19.91386  19.07254
# 99999  196.896053  49.464643  22.62171  21.79745  20.60115  20.00959
#
#               z          spec_obj_ID  class  redshift  plate
# 0      18.79371  6543777369295181824      0  0.634794   5812
# ...

# %% [markdown]
# # Task: create the correlation matrix between the features
#
# What observations can you make on possible features muticollinearity?

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# **Observations:** ?
#
# Check the solutions notebook!

# %% [markdown]
# # Task: create the pair-plot distributions per class
#
# Plot pairwise relationships in out dataset considering the following features only:
# - alpha
# - delta
# - redshift
# - u

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# Some observations:
#
# - `alpha`: Since it is an angle it will range between 0-360.
# - `delta`: Since it is an angle it will range between 0-360.

# %% [markdown]
# # Task: drop data if the contain negative angle values

# %%
#
# CODE
#

# %% [markdown]
# # Task: rank the feature correlations

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# # Task: show the boxplot per feature

# %%
#
# CODE - LIST THE FEATURES
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# Index(['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'spec_obj_ID', 'redshift',
#        'plate'],
#       dtype='object')

# %%
#
# CODE - LOOP OVER THE LIST AND MAKE THE BOX-PLOT FOR EACH FEATURE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# # Task: show the quantile plots per features and class

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# Notes:
#
# From the whiskey plots, it can be concluded that, the majority of ...
# - Stars can be found in the range 0-21 of feature 'u'.
# - Galaxies can be found in the range 21-28 of feature 'u'.
# - Stars can be found in the range 0-20 of 'g'.
# - Galaxies can be found in the range 20-25 of feature 'g'.
# - Stars can be found in the range 0-18 of 'r'.
# - Galaxies can be found in the range 18-25 of feature 'r'.
# - Stars can be found in the range 0-18 of 'i'.
# - Galaxies can be found in the range 18-22 of feature 'i'.
# - Stars can be found in the range 0-17 of 'z'.
# - Galaxies can be found in the range 17-22 of feature 'z'.
# - Stars can be found in the range 0-0.5 of 'spec_obj_ID'.
# - Galaxies can be found in the range 0.5-1.4 of feature 'spec_obj_ID'.
# - Stars can be found in the range 0-4000 of 'plate'.
# - Galaxies can be found in the range 4000-9000 of feature 'plate'.
#
# Since features 'u', 'g', 'r', 'i', and 'z' have similar boxplot plots, they all have strong correlation with each other.

# %% [markdown]
# # Task: drop the extreme outliers
#
# After inpsecting the boxplots you have drawn, drop the following features:
# - z
# - u
# - g
#
# How many events get dropped out?

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# 0

# %% [markdown]
# # Task: Indentify the continuous and non-continuous features
#
# Isolate the features of floating type.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift']

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# ['spec_obj_ID', 'plate']

# %% [markdown]
# # Task: plot the distributions of all continuous features of floating type
#
# Do you observe any gaussian-like distribution?

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# # Task: create the redshift variable for each class in different plots

# %% [markdown]
# Is `redshift` distributing on a comparable range for each class?

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# About the `redshift` feature: if the value is negative (blueshift) and small, the observation is more likely to be a Star.
# If the value is positive(redshift), the observation is more likely to be Galaxy or QSO.

# %% [markdown]
# # Task: apply feature transformation and replot it
#
# Redshift has three dinstict scales depending on the class. We seek a transformer that brings the scales closer. An example is a log-transformation or a power transformation.
#
# Overlay the original and scaled distributions per class. Also, show the overlaid for the inclusive distribution before and after your transformation.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# # Task: create the feature and target datasets
#
# Create the $X$ and $y$ datasets and show the shape for the former.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# (87939, 10)

# %% [markdown]
# # Task: Create data sets for modeling
#
# Split the dataset into random train and test subsets. Set `7733` as random state. Put 1000 events aside for the testing purposes.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL - TRAIN'S SHAPE
#
# Out:
# (86939, 10)

# %%
#
# DO NOT EXECUTE THIS CELL - TEST'S SHAPE
#
# Out:
# (1000, 10)

# %%
#
# DO NOT EXECUTE THIS CELL - NUMBER OF CONTINUOUS AND NON-CONT. FEATURES
#
# Out:
# 10

# %% [markdown]
# # Task: apply transformation on the continuous, floating features
#
# In general, feature rescaling is not strictly necessary. However, for future reference, here we can demonstrate the application of different scalings on different groups of features in the same dataset.
#
#
# Apply the following transformations:
# 1. the power or log transformation on the `redshift` variable, according to your decision made above
# 2. min-max scaling on the rest floating features
#
# Bundle all transformations in a `ColumnTransformer`.
#
# **Important Note:** With respect to the expected output, our transformed output will only contain the transformed (floating features) columns. That's because, the parameter remainder is by default set to 'drop', which implies that all columns which are not subject to transformation are dropped. To avoid this, we should consider setting it to 'passthrough'; this will help us to transform the columns we need and keep the other untouched.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL - MAKE SURE THE SHAPE IS NOT CHANGING - TRAIN SET:
#
# Out:
# (86939, 10)

# %%
#
# DO NOT EXECUTE THIS CELL - MAKE SURE THE SHAPE IS NOT CHANGING - TEST SET:
#
# Out:
# (86939, 10)

# %% [markdown]
# # Task: Feature selection
#
# We want now to consider in our model just the most important features.
#
# `SelectFromModel` is a meta-transformer that can be used alongside our random forests estimator that assigns importance to each feature through a specific attribute (`feature_importances_`).
# The features are considered unimportant and removed if the corresponding importance of the feature values are below the provided threshold parameter. In combination with the threshold criteria, one can use the max_features parameter to set a limit on the number of features to select.
#
# 1. Setup an instance of `SelectFromModel` without  any threshold and list the feature by their importance.
# 2. Compute the percentiles for the feature importances.
# 3. Select all features that rank above the 1st percentile.
#
# Ref: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL - MODEL FIT
#
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
#
# DO NOT EXECUTE THIS CELL - FEATURE IMPORTANCES
#
# Out:
# array([0.00945141, 0.01013873, 0.05529357, 0.05955749, 0.03393547,
#        0.05522548, 0.08612398, 0.63575496, 0.01794579, 0.03657312])

# %%
#
# DO NOT EXECUTE THIS CELL - FEATURE NAMES
#
# Out:
# Index(['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'spec_obj_ID', 'redshift',
#        'plate'],
#       dtype='object')

# %%
#
# CODE - DATAFRAME: FEATURE & IMPORTANCE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
#        feature  importance
# 0        alpha    0.009451
# 1        delta    0.010139
# 8     redshift    0.017946
# 4            r    0.033935
# 9        plate    0.036573
# 5            i    0.055225
# 2            u    0.055294
# 3            g    0.059557
# 6            z    0.086124
# 7  spec_obj_ID    0.635755

# %%
#
# CODE - ADD PERCENTILES
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
#        feature  importance  percentile
# 7  spec_obj_ID    0.635755  100.000000
# 6            z    0.086124   36.424504
# 3            g    0.059557   27.812106
# 2            u    0.055294   21.856357
# 5            i    0.055225   16.327000
# 9        plate    0.036573   10.804453
# 4            r    0.033935    7.147140
# 8     redshift    0.017946    3.753593
# 1        delta    0.010139    1.959015
# 0        alpha    0.009451    0.945141

# %%
#
# CODE - BEST FEATURES
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# ['spec_obj_ID', 'z', 'g', 'u', 'i', 'plate', 'r', 'redshift', 'delta']

# %%
#
# CODE - UNIMPORTANT `WHO CARES` FEATURE(S)
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# ['alpha']

# %% [markdown]
# # Task: Base model
#
# ## Part 1 - create a base model
#
# Use the default setup with random state = 1234.

# %%
#
# CODE - YOUR MODEL
#

# %% [markdown]
# ## Part 2 - Apply the same feature transformations as above
#
# 1. Use the best features only.
# 2. Apply the same feature transformations as in the previous step.
# 3. Split into train & test. Use random state = 7733. The test size is 1000.

# %%
#
# CODE - SPLIT
#

# %%
#
# DO NOT EXECUTE THIS CELL - CHECK SIZE OF THE TRAIN SAMPLE
#
# Out:
# (86939, 9)

# %% [markdown]
# As expected, we have now one feature less.

# %%
#
# CODE - TRANSFORMATIONS (YOU MAY CHECK THE OUTPUT SHAPES)
#

# %% [markdown]
# ## Part 3 - Fit the model & make predictions

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL - MODEL FIT
#
# Out:
# RandomForestClassifier(random_state=1234)

# %%
#
# DO NOT EXECUTE THIS CELL - CHECK THE CLASSES
#
# Out:
# array([0, 1, 2])

# %%
#
# CODE - YOUR PREDICTIONS
#

# %% [markdown]
# ## Part 4 - Evaluate the model
#
# Report the following metrics for the base model
# - Accuracy score
# - Precision score: use `micro` for averaging
# - $F_1$-score: : use `micro` for averaging
# - ROC AUC : use `micro` for averaging and `ovr` (one-vs-rest) for `multi_class`
#
# for the two sets:
# - train
# - test
#
# and observe if there's any indications for model overfitting.
#
# Meaning of `micro`: Calculate metrics globally by counting the total true positives, false negatives and false positives. More info at: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html
#
# Meaning of `ovr`: Stands for One-vs-rest. Computes the AUC of each class against the rest. This treats the multiclass case in the same way as the multilabel case.
#
# Ref: https://scikit-learn.org/stable/modules/model_evaluation.html#the-scoring-parameter-defining-model-evaluation-rules

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# Train set
# {'accuracy': 0.9999884976822829,
#  'precision_micro_score': 0.9999884976822829,
#  'f1_micro_score': 0.9999884976822829,
#  'roc_auc_score': 0.9999999998676967}

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# Test set
# {'accuracy': 0.973,
#  'precision_micro_score': 0.973,
#  'f1_micro_score': 0.973,
#  'roc_auc_score': 0.9953222499999999}

# %% [markdown]
# # Task: Optimize the model with a hypermeter grid search
#
# ## Part 1 - pipeline definition
#
# Define your pipeline with the processing steps:
#  - feature transformation
#   1. min-max scaling for all float variables except `redshift`
#   2. log or power transformation for the `redshift` variable
#  - classification with random state = 1234

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL - PIPELINE
#
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('minmax_scaler',
#                                                   MinMaxScaler(),
#                                                   ['z', 'g', 'u', 'i', 'r',
#                                                    'delta']),
#                                                  ('log_scaler',
#                                                   FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                       validate=True),
#                                                   ['redshift'])])),
#                 ('classifier', RandomForestClassifier(random_state=1234))])

# %% [markdown]
# ## Part 2 - parameters grid definition
#
# Define a dictionary of the model's hyperaparmeters and their search space.
#
# Bear in mind that given he size of your grid, the scan process might result in models that consume a lot of computing memory RAM.

# %%
#
# CODE - YOUR GRID
#

# %% [markdown]
# ## Part 3 - CV strategy
#
# Define a stratified CV startegy with 3 folds.

# %%
#
# CODE
#

# %% [markdown]
# ## Part 4 - Grid search
#
# Perform a grid search and show the best hyperparameter setup. Use `accuracy` as your CV scoring function. Enable multiprocessing to accelarate the gird search and CV.

# %%
#
# CODE
#

# %% [markdown]
# ## Part 5 - Best score
#
# Show the mean score on the test folds for the best model

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# 0.9536085872221877

# %% [markdown]
# ## Part 6 - Best setup
#
# Show the hyperparameters of the best model.

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# {'classifier__max_depth': None,
#  'classifier__max_features': 'sqrt',
#  'classifier__n_estimators': 100}

# %% [markdown]
# # Task: Best model
#
# Create and instance of the best model.
#
# Fit the model.
#
# Evaluate the model.
#
# Compare the training and test metrics to those of the base model.

# %%
#
# CODE - MODEL
#

# %%
#
# DO NOT EXECUTE THIS CELL - MODEL FIT
#
# Out:
# RandomForestClassifier(random_state=1234)

# %%
#
# CODE - PREDICTIONS
#

# %%
#
# CODE - METRICS
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# Train set
# {'accuracy': 0.9999884976822829,
#  'precision_micro_score': 0.9999884976822829,
#  'f1_micro_score': 0.9999884976822829,
#  'roc_auc_score': 0.9999999998676967}

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# Test set
# {'accuracy': 0.973,
#  'precision_micro_score': 0.973,
#  'f1_micro_score': 0.973,
#  'roc_auc_score': 0.9953222499999999}

# %% [markdown]
# # Task: plot the confusion matrix

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL
#

# %% [markdown]
# # Task: Prediction on new data
#
# Make a prediction for this atronomical measurement. Is it a star, galaxy or QSO?
#
# ```
# {'spec_obj_ID': 8.3e+18,
#  'z': 19.3,
#  'g': 21.8,
#  'i': 20.0,
#  'u': 22.6,
#  'plate': 7410.0,
#  'r': 20.6,
#  'redshift': 0.5429,
#  'delta': 49.46}
#  ```

# %%
#
# CODE
#

# %%
#
# DO NOT EXECUTE THIS CELL - THE OBSERVED EVENT
#
# Out:
#     spec_obj_ID     z     g     i     u   plate     r  redshift  delta
# 0  8.300000e+18  19.3  21.8  20.0  22.6  7410.0  20.6    0.5429  49.46

# %%
#
# CODE - PREDICTION
#

# %%
# predicted class
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# array([0])

# %%
# predicted type
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# 'GALAXY'

# %%
# predicted prob
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# 0.96

# %%
# Here is the real observation
#
# THE LAST ROW IN YOUR ORIGINAL DATAFRAME
#

# %%
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# alpha          1.968961e+02
# delta          4.946464e+01
# u              2.262171e+01
# g              2.179745e+01
# r              2.060115e+01
# i              2.000959e+01
# z              1.928075e+01
# spec_obj_ID    8.343152e+18
# class          0.000000e+00
# redshift       5.429442e-01
# plate          7.410000e+03
# Name: 99999, dtype: float64

# %%
# THE CLASS
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# 0

# %%
# THE NAME
#
# DO NOT EXECUTE THIS CELL
#
# Out:
# 'GALAXY'

# %% [markdown]
# <img src="../../misc/galaxy.jpeg" width="500">
#
# # Outstanding!
