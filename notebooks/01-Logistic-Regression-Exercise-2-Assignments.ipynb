# %% [markdown]
# # Essential Machine Learning for Physicists
#
# <p align="right">
#   <img src="../../misc/tum-logo.png" width="93" align="right" />
#   <img src="../../misc/sixt-logo.png" width="70" align="right" />
# <left><em>&copy; Zinonas Zinonos</em></left>
#
# <left><em>For more information, visit <a href='https://github.com/zinon/essential-machine-learning-for-physicists'>essential-machine-learning-for-physicists</a></em></left>.
# ___
# </p>

# %% [markdown]
# # Objective
#
# An experiment was conducted on 5000 participants to study the effects of _age_ and physical health on _hearing loss_, specifically the ability to hear high pitched tones.
#
# The colected data display the result of the study in which participants were evaluated and scored for physical ability and then had to take an audio test (pass/no pass) which evaluated their ability to hear high frequencies.
# The age of the user was also noted.
#
# The objective is to build a logistic regression model that would predict someone's liklihood to hear the high frequency sound based solely on their features (age and physical score).

# %% [markdown]
# ## Data
#
# Data description:
#
# * Features
#     * `age` - Age of participant in years
#     * `physical_score` - Score achieved during physical exam
#
# * Label/Target
#
#     * `test_result` - 0 if no pass, 1 if test passed
#
# Source: Kaggle, ariadavoodi/hearing-test-logistic-regression

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1: Import data
#
# Import the dataset using the file `hearing_test.csv` from the `datasets` folder.

# %%
# CORDIAL CODE HERE

# %% [markdown]
# Show the shape of the dataframe.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# (5000, 3)

# %% [markdown]
# Show the top five rows for the dataframe.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
#     age  physical_score  test_result
# 0  33.0            40.7            1
# 1  50.0            37.2            1
# 2  52.0            24.7            0
# 3  56.0            31.0            0
# 4  35.0            42.9            1

# %% [markdown]
# Show the date type of each column.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# age               float64
# physical_score    float64
# test_result         int64
# dtype: object

# %% [markdown]
# Check for overall null entries for each of the columns.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# age               False
# physical_score    False
# test_result       False
# dtype: bool

# %% [markdown]
# Show the unique values of the target column.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# [1, 0]

# %% [markdown]
# Show a statistical summary of the dataset.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
#                  count      mean        std   min   25%   50%   75%   max
# age             5000.0  51.60900  11.287001  18.0  43.0  51.0  60.0  90.0
# physical_score  5000.0  32.76026   8.169802  -0.0  26.7  35.3  38.9  50.0
# test_result     5000.0   0.60000   0.489947   0.0   0.0   1.0   1.0   1.0

# %% [markdown]
# Check if our target label is balanced or not, i.e. show the number of occurences per class (normalized).

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# 1    0.6
# 0    0.4
# Name: test_result, dtype: float64

# %% [markdown]
# # Task 2: Exploratory Data Analysis and Visualization
#
# Visualize the counts per class.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Draw a box plot to show the target distribution summary with respect to the age. Check for outliers.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Draw a box plot to show the target distribution summary with respect to the physical score. Check for outliers.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Draw a scatter plot of age against our target.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Draw a scatter plot of the physical score against our target.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Draw a scatter plot of the two features per target class.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Plot the pairwise feature relationships in the dataset.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Plot the rectangular data as a color-encoded matrix. Check the varius correlations.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Bonus: create a 3D matplotlib scatter plot. Reference: https://matplotlib.org/stable/gallery/mplot3d/scatter3d.html.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# # Task 3: Train & Test Split
#
# Create a the $X$ (features) and $y$ (target) datasets.

# %%
# CORDIAL CODE HERE

# %% [markdown]
# Split the data into train (90%) and test (the remaining 10%) sets. Use 2022 as random state.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (splitting)

# %% [markdown]
# # Task 4: Scale the features.
#
# Standardize the features by removing the mean and scaling to unit variance.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (scaler instance)

# %%
# train set
# CORDIAL CODE HERE

# %%
# test set
# CORDIAL CODE HERE

# %% [markdown]
# Show the size of the train and test samples.

# %%
# CORDIAL CODE HERE: X train

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# (4500, 2)

# %%
# CORDIAL CODE HERE: X test

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# (500, 2)

# %% [markdown]
# # Task 5: Build a Logistic Regression Model
#
# ## Training & Optimization
#
# Create an instance of the model.
# Define a reasonable grid search over the following hyperparmeters:
# - `Cs`: the inverse of regularization strength. Tip: define a grid of 10 Cs values in a logarithmic scale between 1e-4 and 1e4.
# - `l1_ratios`: the Elastic-Net mixing parameter between the `l1` and `l2` regularizations.
#
# Notes:
# - Set the `penalty` model parmater to "elasticnet".
# - Set the `solver` model parameter to "saga".
#
# Train the model on the scaled version of the data.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (your grids)

# %%
# CORDIAL CODE HERE (your model's instance)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# LogisticRegressionCV(Cs=array([1.00000000e-04, 7.74263683e-04, 5.99484250e-03, 4.64158883e-02,
#        3.59381366e-01, 2.78255940e+00, 2.15443469e+01, 1.66810054e+02,
#        1.29154967e+03, 1.00000000e+04]),
#                      l1_ratios=[0, 0.1, 0.25, 0.5, 0.75, 0.8, 0.9, 0.95, 0.97,
#                                 0.99, 1],
#                      n_jobs=7, penalty='elasticnet', solver='saga')

# %% [markdown]
# Show the predicted classes of the model.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# array([0, 1])

# %% [markdown]
# Show the best model parameters.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking (C1)
# Out:
# array([0.00599484])

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking (l1 ratio)
# Out:
# array([0.95])

# %% [markdown]
# ## Coefficient Interpretation
#
# Show the model coefficients.
#
# Remember that rhese coeffecients relate to the *odds* and can not be directly interpreted as in linear regression. It is much easier to understand and interpret the relationship between the coefficients than it is to interpret the coefficients relationship with the probability of the target/label class.
#
# For a continuous independent variable the odds ratio can be defined as:
#
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/18dc1087bc50b9c1afee6820aad1858704b43ea3" >

# %% [markdown]
# This exponential relationship provides an interpretation for $$\beta _{1}$$

# %% [markdown]
# The odds multiply by $${e^\beta _{1}}$$ for every 1-unit increase in x.

# %%
# CORDIAL CODE HERE (coeffs)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# array([[-0.51136819,  2.15019775]])

# %% [markdown]
# Draw the weights of the logistic regression.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# What are the correlation coefficients found in Task 2?

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# age              -0.683171
# physical_score    0.792716
# Name: test_result, dtype: float64

# %% [markdown]
# What are the two input features? Show them in order.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# ['age', 'physical_score']

# %% [markdown]
# Interpretation of the above result:
#
# * We can expect the **odds** of passing the test to **decrease** (the original coeff was negative) per unit increase of the `age`.
# * We can expect the **odds** of passing the test to **increase** (the original coeff was positive) per unit increase of the `physical score`.
#
# * Based on the ratios with each other, the `physical_score` indicator is a stronger predictor than `age`.

# %% [markdown]
# ## Predicted Boundary
#
# Since we are dealing with a classification problem containing only 2 features, it is then possible to observe the decision function boundary.
# The boundary is the rule used by our predictive model to affect a class label given the feature values of the sample.
#
# Here, we will use the class `DecisionBoundaryDisplay`. Ref: https://scikit-learn.org/stable/modules/generated/sklearn.inspection.DecisionBoundaryDisplay.html.
#
# This tool allows us to gain some insights by plotting the decision function boundary learned by the classifier in a 2 dimensional feature space.
# Notice however that in more realistic machine learning contexts, one would typically fit on more than two features at once and therefore it would not be possible to display such a visualization of the decision boundary in general.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Can the decision function be represented by a line separating the 2 classes?
# Is the line is oblique?

# %%
# the answer in the solutions notebook

# %% [markdown]
# # Task 6: Model Performance
#
# Find the model's accuracy.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (predictions)

# %%
# CORDIAL CODE HERE (accuracy)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# 0.93

# %% [markdown]
# Show the confusion matrix as text.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (matrix)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# array([[173,  23],
#        [ 12, 292]])

# %% [markdown]
# Visualize the confusion matrix.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Visualize the confusion matrix normalized over the true conditions (rows).

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Display the classification report.

# %%
# CORDIAL CODE HERE

# %%
# KEEP ME ALIVE for cross-checking
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       196
#            1       0.93      0.96      0.94       304
#
#     accuracy                           0.93       500
#    macro avg       0.93      0.92      0.93       500
# weighted avg       0.93      0.93      0.93       500

# %% [markdown]
# # Task 7: Evaluating Curves and AUC
#
# Plot the ROC curve.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (curve)

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Calculate the ROC AUC. Is your result in agreement with the value reported in the previous plot?

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (AUC score calculation)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# 0.9725765306122449

# %% [markdown]
# Plot the Precision-Recall curve.

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (curve)

# %%
# KEEP ME ALIVE for cross-checking

# %% [markdown]
# Calculate the Precision-Recall AUC. Is your result in agreement with the value reported in the previous plot?

# %%
# CORDIAL CODE HERE (AUC calculation)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# 0.9791619999347455

# %% [markdown]
# What's the average precision score?

# %%
# CORDIAL CODE HERE (imports)

# %%
# CORDIAL CODE HERE (calculation)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# 0.9791871940102425

# %% [markdown]
# # Task 8: Real-time prediction
#
# Aristotle Onassis is a multi-billionaire, 55-years-old participant and achieves a score of 24.4 during the physical exam.
#
# What's the chance that he passes the hearing test?

# %%
# CODE (your input data)

# %%
# CODE (your scaling)

# %%
# CODE (show the classes here)

# %%
# KEEP ME ALIVE for cross-checking
# Out:
# /home/zinonas/Documents/EssentialML/EssentialML/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0, 1])

# %%
# predicted class
# KEEP ME ALIVE for cross-checking
# Out:
# 0

# %%
# predicted probabilities
# KEEP ME ALIVE for cross-checking
# Out:
# array([[0.86553958, 0.13446042]])

# %% [markdown]
# What that model says on a similar instance in training data?

# %%
X_train.iloc[0]

# %%
X_train_scaled[0]

# %%
y_train.iloc[0]

# %%
# predicted class
model.predict(X_train_scaled[0].reshape(1, -1))[0]

# %%
# predicted chances
model.predict_proba(X_train_scaled[0].reshape(1, -1))

# %% [markdown]
# # Outstanding!
